# %% [markdown]
# # AIRBNB RAGSystem

# %% [markdown]
# - source - https://builtin.com/articles/how-to-build-a-rag-system

# %%
from datasets import load_dataset
import pandas as pd
import os

# https://huggingface.co/datasets/MongoDB/embedded_movies
# Make sure you have an Hugging Face token(HF_TOKEN) in your development environemnt
dataset = load_dataset("MongoDB/airbnb_embeddings")

# Convert the dataset to a pandas dataframe
dataset_df = pd.DataFrame(dataset['train'])

with open('hf_key','r') as f:
    key = f.readline()

with open('openai_key.txt', 'r') as f:
    openai_key = f.readline()

os.environ['HF_TOKEN'] = key
os.environ['OPENAI_API_KEY'] = openai_key

dataset_df.head(5)
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10021707  https://www.airbnb.com/rooms/10021707
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10009999  https://www.airbnb.com/rooms/10009999
# 4  10047964  https://www.airbnb.com/rooms/10047964
#
#                                name  \
# 0           Ribeira Charming Duplex
# 1          Private Room in Bushwick
# 2  Ocean View Waikiki Marina w/prkg
# 3      Horto flat with small garden
# 4    Charming Flat in Downtown Moda
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  Here exists a very cozy room for rent in a sha...
# 2  A short distance from Honolulu's billion dolla...
# 3  One bedroom + sofa-bed in quiet and bucolic ne...
# 4  Fully furnished 3+1 flat decorated with vintag...
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
# 1
# 2  Great studio located on Ala Moana across the s...
# 3  Lovely one bedroom + sofa-bed in the living ro...
# 4  The apartment is composed of 1 big bedroom wit...
#
#                                          description  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  Here exists a very cozy room for rent in a sha...
# 2  A short distance from Honolulu's billion dolla...
# 3  One bedroom + sofa-bed in quiet and bucolic ne...
# 4  Fully furnished 3+1 flat decorated with vintag...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
# 1
# 2             You can breath ocean as well as aloha.
# 3  This charming ground floor flat is located in ...
# 4  With its diversity Moda- Kadikoy is one of the...
#
#                                                notes  \
# 0  Lose yourself in the narrow streets and stairc...
# 1
# 2
# 3  There´s a table in the living room now, that d...
# 4
#
#                                              transit  \
# 0  Transport: • Metro station and S. Bento railwa...
# 1
# 2  Honolulu does have a very good air conditioned...
# 3  Easy access to transport (bus, taxi, car) and ...
# 4
#
#                                               access  ...  \
# 0  We are always available to help guests. The ho...  ...
# 1                                                     ...
# 2                           Pool, hot tub and tennis  ...
# 3                                                     ...
# 4                                                     ...
#
#                                               images  \
# 0  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 1  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 2  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 3  {'thumbnail_url': '', 'medium_url': '', 'pictu...
# 4  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
#                                                 host  \
# 0  {'host_id': '51399391', 'host_url': 'https://w...
# 1  {'host_id': '11275734', 'host_url': 'https://w...
# 2  {'host_id': '5448114', 'host_url': 'https://ww...
# 3  {'host_id': '1282196', 'host_url': 'https://ww...
# 4  {'host_id': '1241644', 'host_url': 'https://ww...
#
#                                              address  \
# 0  {'street': 'Porto, Porto, Portugal', 'suburb':...
# 1  {'street': 'Brooklyn, NY, United States', 'sub...
# 2  {'street': 'Honolulu, HI, United States', 'sub...
# 3  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# 4  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
#
#                                         availability  \
# 0  {'availability_30': 28, 'availability_60': 47,...
# 1  {'availability_30': 0, 'availability_60': 0, '...
# 2  {'availability_30': 16, 'availability_60': 46,...
# 3  {'availability_30': 0, 'availability_60': 0, '...
# 4  {'availability_30': 27, 'availability_60': 57,...
#
#                                        review_scores  \
# 0  {'review_scores_accuracy': 9, 'review_scores_c...
# 1  {'review_scores_accuracy': 10, 'review_scores_...
# 2  {'review_scores_accuracy': 9, 'review_scores_c...
# 3  {'review_scores_accuracy': None, 'review_score...
# 4  {'review_scores_accuracy': 10, 'review_scores_...
#
#                                              reviews  weekly_price  \
# 0  [{'_id': '58663741', 'date': 2016-01-03 05:00:...           NaN
# 1  [{'_id': '61050713', 'date': 2016-01-31 05:00:...           NaN
# 2  [{'_id': '4765259', 'date': 2013-05-24 04:00:0...         650.0
# 3                                                 []        1492.0
# 4  [{'_id': '68162172', 'date': 2016-04-02 04:00:...           NaN
#
#   monthly_price                                    text_embeddings  \
# 0           NaN  [0.0123710884, -0.0180913936, -0.016843712, -0...
# 1           NaN  [0.0153845912, -0.0348115042, -0.0093448907, 0...
# 2        2150.0  [-0.0400562622, -0.0405789167, 0.000644172, 0....
# 3        4849.0  [-0.063234821, 0.0017937823, -0.0243996996, -0...
# 4           NaN  [0.023723349, 0.0064210771, -0.0339970738, -0....
#
#                                     image_embeddings
# 0  [-0.1302358955, 0.1534578055, 0.0199299306, -0...
# 1  [0.0340401195, 0.1742489338, -0.1572628617, 0....
# 2  [-0.1640156209, 0.1256971657, 0.6594450474, -0...
# 3  [-0.1292964518, 0.037789464, 0.2443587631, 0.0...
# 4  [-0.1006749049, 0.4022984803, -0.1821258366, 0...
#
# [5 rows x 43 columns]

# %%
import json

# Read JSON file
with open('mongodb.json', 'r') as file:
    mongo_connection = json.load(file)

# %%
dataset_df = dataset_df.drop(columns=['text_embeddings'])

# %%
from llama_index.core.settings import Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding

embed_model = OpenAIEmbedding(model="text-embedding-3-small", dimensions=1024)
llm = OpenAI()

Settings.llm = llm
Settings.embed_model = embed_model

# %%
import json
from llama_index.core import Document
from llama_index.core.schema import MetadataMode

# Convert the DataFrame to a JSON string representation
documents_json = dataset_df.to_json(orient='records')

# Load the JSON string into a Python list of dictionaries
documents_list = json.loads(documents_json)

llama_documents = []

for document in documents_list:

  # Value for metadata must be one of (str, int, float, None)
  document["amenities"] = json.dumps(document["amenities"])
  document["images"] = json.dumps(document["images"])
  document["host"] = json.dumps(document["host"])
  document["address"] = json.dumps(document["address"])
  document["availability"] = json.dumps(document["availability"])
  document["review_scores"] = json.dumps(document["review_scores"])
  document["reviews"] = json.dumps(document["reviews"])
  document["image_embeddings"] = json.dumps(document["image_embeddings"])


  # Create a Document object with the text and excluded metadata for llm and embedding models
  llama_document = Document(
      text=document["description"],
      metadata=document,
      excluded_llm_metadata_keys=["_id", "transit", "minimum_nights", "maximum_nights", "cancellation_policy", "last_scraped", "calendar_last_scraped", "first_review", "last_review", "security_deposit", "cleaning_fee", "guests_included", "host", "availability", "reviews", "image_embeddings"],
      excluded_embed_metadata_keys=["_id", "transit", "minimum_nights", "maximum_nights", "cancellation_policy", "last_scraped", "calendar_last_scraped", "first_review", "last_review", "security_deposit", "cleaning_fee", "guests_included", "host", "availability", "reviews", "image_embeddings"],
      metadata_template="{key}=>{value}",
      text_template="Metadata: {metadata_str}\n-----\nContent: {content}",
      )

  llama_documents.append(llama_document)

# Observing an example of what the LLM and Embedding model receive as input
print(
    "\nThe LLM sees this: \n",
    llama_documents[0].get_content(metadata_mode=MetadataMode.LLM),
)
print(
    "\nThe Embedding model sees this: \n",
    llama_documents[0].get_content(metadata_mode=MetadataMode.EMBED),
)
# Out:
# The LLM sees this:
#  Metadata: listing_url=>https://www.airbnb.com/rooms/10006546
# name=>Ribeira Charming Duplex
# summary=>Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.
# space=>Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit.
# description=>Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character. Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit. We are always available to help guests
# neighborhood_overview=>In the neighborhood of the river, you can find several restaurants as varied flavors, but without forgetting the so traditional northern food. You can also find several bars and pubs to unwind after a day's visit to the magnificent Port. To enjoy the Douro River can board the boats that daily make the ride of six bridges. You can also embark towards Régua, Barca d'Alva, Pinhão, etc and enjoy the Douro Wine Region, World Heritage of Humanity. The Infante's house is a few meters and no doubt it deserves a visit. They abound grocery stores, bakeries, etc. to make your meals. Souvenir shop, wine cellars, etc. to bring some souvenirs.
# notes=>Lose yourself in the narrow streets and staircases zone, have lunch in pubs and typical restaurants, and find the renovated cafes and shops in town. If you like exercise, rent a bicycle in the area and ride along the river to the sea, where it will enter beautiful beaches and terraces for everyone. The area is safe, find the bus stops 1min and metro line 5min. The bustling nightlife is a 10 min walk, where the streets are filled with people and entertainment for all. But Porto is much more than the historical center, here is modern museums, concert halls, clean and cared for beaches and surf all year round. Walk through the Ponte D. Luis and visit the different Caves of Port wine, where you will enjoy the famous port wine. Porto is a spoken city everywhere in the world as the best to be visited and savored by all ... natural beauty, culture, tradition, river, sea, beach, single people, typical food, and we are among those who best receive tourists, confirm! Come visit us and feel at ho
# access=>We are always available to help guests. The house is fully available to guests. We are always ready to assist guests. when possible we pick the guests at the airport.  This service transfer have a cost per person. We will also have service "meal at home" with a diverse menu and the taste of each. Enjoy the moment!
# interaction=>Cot - 10 € / night Dog - € 7,5 / night
# house_rules=>Make the house your home...
# property_type=>House
# room_type=>Entire home/apt
# bed_type=>Real Bed
# accommodates=>8
# bedrooms=>3.0
# beds=>5.0
# number_of_reviews=>51
# bathrooms=>1.0
# amenities=>["TV", "Cable TV", "Wifi", "Kitchen", "Paid parking off premises", "Smoking allowed", "Pets allowed", "Buzzer/wireless intercom", "Heating", "Family/kid friendly", "Washer", "First aid kit", "Fire extinguisher", "Essentials", "Hangers", "Hair dryer", "Iron", "Pack \u2019n Play/travel crib", "Room-darkening shades", "Hot water", "Bed linens", "Extra pillows and blankets", "Microwave", "Coffee maker", "Refrigerator", "Dishwasher", "Dishes and silverware", "Cooking basics", "Oven", "Stove", "Cleaning before checkout", "Waterfront"]
# price=>80
# extra_people=>15
# images=>{"thumbnail_url": "", "medium_url": "", "picture_url": "https://a0.muscache.com/im/pictures/e83e702f-ef49-40fb-8fa0-6512d7e26e9b.jpg?aki_policy=large", "xl_picture_url": ""}
# address=>{"street": "Porto, Porto, Portugal", "suburb": "", "government_area": "Cedofeita, Ildefonso, S\u00e9, Miragaia, Nicolau, Vit\u00f3ria", "market": "Porto", "country": "Portugal", "country_code": "PT", "location": {"type": "Point", "coordinates": [-8.61308, 41.1413], "is_location_exact": false}}
# review_scores=>{"review_scores_accuracy": 9, "review_scores_cleanliness": 9, "review_scores_checkin": 10, "review_scores_communication": 10, "review_scores_location": 10, "review_scores_value": 9, "review_scores_rating": 89}
# weekly_price=>None
# monthly_price=>None
# -----
# Content: Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character. Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit. We are always available to help guests
#
# The Embedding model sees this:
#  Metadata: listing_url=>https://www.airbnb.com/rooms/10006546
# name=>Ribeira Charming Duplex
# summary=>Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.
# space=>Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit.
# description=>Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character. Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit. We are always available to help guests
# neighborhood_overview=>In the neighborhood of the river, you can find several restaurants as varied flavors, but without forgetting the so traditional northern food. You can also find several bars and pubs to unwind after a day's visit to the magnificent Port. To enjoy the Douro River can board the boats that daily make the ride of six bridges. You can also embark towards Régua, Barca d'Alva, Pinhão, etc and enjoy the Douro Wine Region, World Heritage of Humanity. The Infante's house is a few meters and no doubt it deserves a visit. They abound grocery stores, bakeries, etc. to make your meals. Souvenir shop, wine cellars, etc. to bring some souvenirs.
# notes=>Lose yourself in the narrow streets and staircases zone, have lunch in pubs and typical restaurants, and find the renovated cafes and shops in town. If you like exercise, rent a bicycle in the area and ride along the river to the sea, where it will enter beautiful beaches and terraces for everyone. The area is safe, find the bus stops 1min and metro line 5min. The bustling nightlife is a 10 min walk, where the streets are filled with people and entertainment for all. But Porto is much more than the historical center, here is modern museums, concert halls, clean and cared for beaches and surf all year round. Walk through the Ponte D. Luis and visit the different Caves of Port wine, where you will enjoy the famous port wine. Porto is a spoken city everywhere in the world as the best to be visited and savored by all ... natural beauty, culture, tradition, river, sea, beach, single people, typical food, and we are among those who best receive tourists, confirm! Come visit us and feel at ho
# access=>We are always available to help guests. The house is fully available to guests. We are always ready to assist guests. when possible we pick the guests at the airport.  This service transfer have a cost per person. We will also have service "meal at home" with a diverse menu and the taste of each. Enjoy the moment!
# interaction=>Cot - 10 € / night Dog - € 7,5 / night
# house_rules=>Make the house your home...
# property_type=>House
# room_type=>Entire home/apt
# bed_type=>Real Bed
# accommodates=>8
# bedrooms=>3.0
# beds=>5.0
# number_of_reviews=>51
# bathrooms=>1.0
# amenities=>["TV", "Cable TV", "Wifi", "Kitchen", "Paid parking off premises", "Smoking allowed", "Pets allowed", "Buzzer/wireless intercom", "Heating", "Family/kid friendly", "Washer", "First aid kit", "Fire extinguisher", "Essentials", "Hangers", "Hair dryer", "Iron", "Pack \u2019n Play/travel crib", "Room-darkening shades", "Hot water", "Bed linens", "Extra pillows and blankets", "Microwave", "Coffee maker", "Refrigerator", "Dishwasher", "Dishes and silverware", "Cooking basics", "Oven", "Stove", "Cleaning before checkout", "Waterfront"]
# price=>80
# extra_people=>15
# images=>{"thumbnail_url": "", "medium_url": "", "picture_url": "https://a0.muscache.com/im/pictures/e83e702f-ef49-40fb-8fa0-6512d7e26e9b.jpg?aki_policy=large", "xl_picture_url": ""}
# address=>{"street": "Porto, Porto, Portugal", "suburb": "", "government_area": "Cedofeita, Ildefonso, S\u00e9, Miragaia, Nicolau, Vit\u00f3ria", "market": "Porto", "country": "Portugal", "country_code": "PT", "location": {"type": "Point", "coordinates": [-8.61308, 41.1413], "is_location_exact": false}}
# review_scores=>{"review_scores_accuracy": 9, "review_scores_cleanliness": 9, "review_scores_checkin": 10, "review_scores_communication": 10, "review_scores_location": 10, "review_scores_value": 9, "review_scores_rating": 89}
# weekly_price=>None
# monthly_price=>None
# -----
# Content: Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character. Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit. We are always available to help guests

# %%
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.schema import MetadataMode

parser = SentenceSplitter(chunk_size=5000)
nodes = parser.get_nodes_from_documents(llama_documents)

for node in nodes:
    node_embedding = embed_model.get_text_embedding(
        node.get_content(metadata_mode=MetadataMode.EMBED)
    )
    
    node.embedding = node_embedding

# %%
node_content = node.get_content(metadata_mode=MetadataMode.EMBED)
node_content
# Out:
# 'Metadata: listing_url=>https://www.airbnb.com/rooms/10006546\nname=>Ribeira Charming Duplex\nsummary=>Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.\nspace=>Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit.\ndescription=>Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character. Privileged views of the Douro River and Ribeira square, our apartment offers the perfect conditions to discover the history and the charm of Porto. Apartment comfortable, charming, romantic and cozy in the heart of Ribeira. Within walking distance of all the most emblematic places of the city of Porto. The apartment is fully equipped to host 8 people, with cooker, oven, washing machine, dishwasher, microwave, coffee machine (Nespresso) and kettle. The apartment is located in a very typical area of the city that allows to cross with the most picturesque population of the city, welcoming, genuine and happy people that fills the streets with his outspoken speech and contagious with your sincere generosity, wrapped in a only parochial spirit. We are always available to help guests\nneighborhood_overview=>In the neighborhood of the river, you can find several restaurants as varied flavors, but without forgetting the so traditional northern food. You can also find several bars and pubs to unwind after a day\'s visit to the magnificent Port. To enjoy the Douro River can board the boats that daily make the ride of six bridges. You can also embark towards Régua, Barca d\'Alva, Pinhão, etc and enjoy the Douro Wine Region, World Heritage of Humanity. The Infante\'s house is a few meters and no doubt it deserves a visit. They abound grocery stores, bakeries, etc. to make your meals. Souvenir shop, wine cellars, etc. to bring some souvenirs.\nnotes=>Lose yourself in the narrow streets and staircases zone, have lunch in pubs and typical restaurants, and find the renovated cafes and shops in town. If you like exercise, rent a bicycle in the area and ride along the river to the sea, where it will enter beautiful beaches and terraces for everyone. The area is safe, find the bus stops 1min and metro line 5min. The bustling nightlife is a 10 min walk, where the streets are filled with people and entertainment for all. But Porto is much more than the historical center, here is modern museums, concert halls, clean and cared for beaches and surf all year round. Walk through the Ponte D. Luis and visit the different Caves of Port wine, where you will enjoy the famous port wine. Porto is a spoken city everywhere in the world as the best to be visited and savored by all ... natural beauty, culture, tradition, river, sea, beach, single people, typical food, and we are among those who best receive tourists, confirm! Come visit us and feel at ho\naccess=>We are always available to help guests. The house is fully available to guests. We are always ready to assist guests. when possible we pick the guests at the airport.  This service transfer have a cost per person. We will also ha ...

# %%
# import pymongo
# import certifi

# def get_mongo_client(mongo_uri):
#   """Establish connection to the MongoDB."""
#   try:
#     client = pymongo.MongoClient(mongo_uri)
#     print("Connection to MongoDB successful")
#     return client
#   except pymongo.errors.ConnectionFailure as e:
#     print(f"Connection failed: {e}")
#     return None

# mongo_uri = mongo_connection['connection_uri']
# if not mongo_uri:
#   print("MONGO_URI not set in environment variables")

# mongo_client = get_mongo_client(mongo_uri)

import chromadb
from chromadb.config import Settings

# Initialize ChromaDB with default settings
settings = Settings()
client = chromadb.Client(settings)

DB_NAME="airbnb"
COLLECTION_NAME="listings_reviews"

collection = client.create_collection(COLLECTION_NAME)
# db = mongo_client[DB_NAME]
# collection = db[COLLECTION_NAME]

# %%
import numpy as np

# Prepare lists to store embeddings and metadata
embeddings = []
documents = []
ids = []
# Add vectors to the collection
for node in nodes:
    node_content = node.get_content(metadata_mode=MetadataMode.EMBED)
    # Store the embedding and node content
    embeddings.append(node.embedding)
    documents.append(node_content)
    ids.append(node.id_)
    
# Insert embeddings and metadata into ChromaDB collection
i = 0

while i < len(embeddings):
    collection.add(embeddings=embeddings[i:i+2000], documents=documents[i:i+2000], ids=ids[i:i+2000])
    i=i+2000

# %%
# Convert a query into a vector
query_text = "Give a good and friendly host and a friendly neighborhood"  # replace with your actual query
query_vector = embed_model.get_text_embedding(query_text)

# %%
k = 5  # Number of nearest neighbors to search for
results = collection.query(
    query_embeddings=[query_vector], 
    n_results=k
)

# %%
# Display the results
result_ids = results['ids']
result_distances = results['distances']
result_metadatas = results['metadatas']

# Display the results
print("Indices of nearest neighbors:", results["ids"])
print("Distances to nearest neighbors:", results["distances"])
# Out:
# Indices of nearest neighbors: [['4617dab2-e287-4050-aa8d-9419ad35c481', 'e28c6697-0343-4f36-9b54-d7ab3ec9c201', '1cfbfb8e-14c9-4804-9f28-e5d35c33c57a', '86e3f41c-5b14-4d07-8dd9-9767870b0c80', 'b2c6f5d3-9a5c-4d1f-9010-215371d24001']]
# Distances to nearest neighbors: [[1.0906058549880981, 1.1123956441879272, 1.1154425144195557, 1.119917869567871, 1.1333705186843872]]

# %%
collection.get(result_ids[0])['documents']
# Out:
# ['Metadata: listing_url=>https://www.airbnb.com/rooms/1370405\nname=>Fresh, Simple Sleep in Brooklyn!\nsummary=>A budget traveler\'s DREAM! Queen bed, shared bathroom, subway access, and SEVEN YEAR/FIVE STAR Superhosts, all for a very reasonable price! Plus, 2 dogs to call your best friends for the duration of your stay :)\nspace=>:) FIRST THINGS FIRST! :) Airbnb has a COMMUNITY VIBE. We invite strangers into our home and welcome you as family, while giving you the SPACE AND RESPECT you need on your vacation. As such, we have a few requests when inquiring so that you get a QUICK AND POSITIVE acceptance! 1. PROFILE: Have a PHOTO of YOU, along with a BIO to let us know a little bit about you! (Where you\'re from, what you do, etc.) Please, VERIFY YOUR ID! 2. TRAVEL: Tell us about your TRIP (travel plans TO NYC, duration, etc.) and any special requirements you may have. 3. AGREEMENT: Confirm you have READ THE TERMS of stay, POLICY on check-in and check-out, and the very few house rules. 4. GET HAPPY!: If we have the space and you\'ve done #1,2,3, we WELCOME you gladly! Hosting people from the around the world is awesome and you\'ve chosen the BEST VALUE anywhere! **** Our home is a BUDGET TRAVELER\'S DREAM!! A peaceful oasis to crash at while you\'re out all day exploring the city. Easy subway access to Manhattan on two\ndescription=>A budget traveler\'s DREAM! Queen bed, shared bathroom, subway access, and SEVEN YEAR/FIVE STAR Superhosts, all for a very reasonable price! Plus, 2 dogs to call your best friends for the duration of your stay :) :) FIRST THINGS FIRST! :) Airbnb has a COMMUNITY VIBE. We invite strangers into our home and welcome you as family, while giving you the SPACE AND RESPECT you need on your vacation. As such, we have a few requests when inquiring so that you get a QUICK AND POSITIVE acceptance! 1. PROFILE: Have a PHOTO of YOU, along with a BIO to let us know a little bit about you! (Where you\'re from, what you do, etc.) Please, VERIFY YOUR ID! 2. TRAVEL: Tell us about your TRIP (travel plans TO NYC, duration, etc.) and any special requirements you may have. 3. AGREEMENT: Confirm you have READ THE TERMS of stay, POLICY on check-in and check-out, and the very few house rules. 4. GET HAPPY!: If we have the space and you\'ve done #1,2,3, we WELCOME you gladly! Hosting people from the around the world\nneighborhood_overview=>About the NEIGHBORHOOD:::      The neighborhood is Flatbush, bordering Ditmas Park and Prospect-Lefferts Gardens. This is NOT hipster paradise, and it\'s NOT gangster\'s paradise either!  Our neighborhood is very residential and typically quieter than most urban cities. The summertime is louder on the block because very few people have air conditioning and enjoy hanging outside. The neighbors are friendly, so say hello as you pass! The ages of the neighborhood are very diverse (young children to elderly homeowners who have been here for 40 years). Flatbush has a lot of local charm and people with hearts of gold.  Jamaican food is plentiful (jerk chicken- yeah!); there is also a local donut shop nearby, Subway, Thai, sushi, pizza, and Indian food for delivery or a 5-15 minute walk to the restaurant, as well as many chain stores like Dominos, Dunkin\' Donuts, IHOP, and Walgreens drug store. There is also a Planet Fitness (handy for Black-Card members!) Just a 10 minute walk down the road is\nnotes=>**NOTE: Though our CHECK-IN and CHECK-OUT times are VERY FLEXIBLE, it is important to understand that many times, we have guests back to back.  CHECK IN: This means, if you are coming in on a red-eye flight and are arriving early in the morning, the previous guest may still be occupying the room until after we have both left for work meetings. As we work and are not a full-time business (just a couple renting out a room to meet awesome travelers), we may not be able to change the sheets and thoroughly clean the room until later in the evening, sometimes as late as 7pm. You are welcome to drop your ba ...
#  'Metadata: listing_url=>https://www.airbnb.com/rooms/21111727\nname=>Urban Venture @McGill Ghetto Social experience\nsummary=>Come live with us to experience a very different side of Montreal lifestyle - never to be found at hotels. This Victorian townhouse is located in a very lively student neighborhood which is also only steps away from Downtown and Public transport. You will be hosted by Ayan and Frank the Cat and you will also meet other travelers from all over the world during your stay. Guests will be provided with high-speed wifi, fresh towels, linens, and if you are lucky you might get to taste our cooking!\nspace=>We live in a Victorian townhouse spread on two floors. There are two rooms on the main floor, where the kitchen and the living room is. There are three more rooms upstairs along with 1 and a half bathroom. Three of the rooms are for guests and we keep two for ourselves. This is definitely not the fanciest place but we recently moved in and its a work in progress. We decorate bit by bit each day and we would love your help and ideas! The living room is often used as a psuedo-base for our operations with supplies stocked and there might be a small commotion during the mornings. On the bright side you will run into many sociable people.  Even with all the people around you will definitely have exclusive access to your room but this stay is more about the memories you will take home and the ideas we will share than about sleeping in your room. We have done our best to make your rooms as cozy as possible but we hope we don\'t get you too comfortable in them, we want you to come and share you\ndescription=>Come live with us to experience a very different side of Montreal lifestyle - never to be found at hotels. This Victorian townhouse is located in a very lively student neighborhood which is also only steps away from Downtown and Public transport. You will be hosted by Ayan and Frank the Cat and you will also meet other travelers from all over the world during your stay. Guests will be provided with high-speed wifi, fresh towels, linens, and if you are lucky you might get to taste our cooking! We live in a Victorian townhouse spread on two floors. There are two rooms on the main floor, where the kitchen and the living room is. There are three more rooms upstairs along with 1 and a half bathroom. Three of the rooms are for guests and we keep two for ourselves. This is definitely not the fanciest place but we recently moved in and its a work in progress. We decorate bit by bit each day and we would love your help and ideas! The living room is often used as a psuedo-base for our operations\nneighborhood_overview=>The apartment is at border of Plateau Mont-Royal and Downtown Montreal. The Plateau is characterized by brightly colored houses, cafés, book shops, and a laissez-faire attitude. It\'s the location of some famous attractions on Saint Laurent Boulevard, including Schwartz\'s Deli (famous for its Montreal smoked meat), and a weekend street fair during the summer that sees extremely crowded streets. In 1997, Utne Reader rated it one of the 15 "hippest" neighborhoods in North America. The neighbourhoods of Mile End, Côte Saint-Louis, and Milton-Parc (including the McGill Ghetto) are also located in the borough. Montreal\'s Little Portugal neighbourhood is situated in the western portion of the borough. The borough is largely composed of the well-known Plateau neighbourhood, famous for its bohemian reputation and characteristic architecture. The downtown region houses many corporate headquarters as well a large majority of the city\'s skyscrapers — which, by law, cannot be greater in height than\nnotes=>This is our home and we expect guests to feel like its their own and respect it likewise. We will be charging sales tax as community fee from Octob (Phone number hidden by Airbnb) onwards.\naccess=>Guests will have private access to their rooms and to all the shared common spaces.\ninteraction=>We live at this l ...
#  'Metadata: listing_url=>https://www.airbnb.com/rooms/1584281\nname=>Cozy In The Heart Of The Plateau\nsummary=>Sunlight, Style and homely feeling in 2 rooms of my spacious  Plateau Apartment which can host up to 4 people! Just off Avenue Mont Royal you\'ll find the best Montreal has to offer only a Stone\'s Throw away and for everything else the subway around the corner!\nspace=>( PLEASE INTRODUCE YOURSELF PROPERLY WHEN SENDING US A REQUEST, WE ARE OPENING OUR HOME TO YOU AFTER-ALL)  Hi fellow Traveller, I love Airbnb myself and had such amazing experiences that now, since I have the luxury of a spare room, I would like to give back some of the loving! Im looking forward to host people who share the same Airbnb spirit of community and sharing. The room you’ll be staying in is beautiful and bright with lots of privacy and will accommodate all your needs while you\'re on the road. Its one of three Rooms in this typical Plateaux Apartment with wooden floor, tiny balcony and direct access to the Backyard. Your room will have a queen size bed and is actually the one who gets the most sunlight in the house.\ndescription=>Sunlight, Style and homely feeling in 2 rooms of my spacious  Plateau Apartment which can host up to 4 people! Just off Avenue Mont Royal you\'ll find the best Montreal has to offer only a Stone\'s Throw away and for everything else the subway around the corner! ( PLEASE INTRODUCE YOURSELF PROPERLY WHEN SENDING US A REQUEST, WE ARE OPENING OUR HOME TO YOU AFTER-ALL)  Hi fellow Traveller, I love Airbnb myself and had such amazing experiences that now, since I have the luxury of a spare room, I would like to give back some of the loving! Im looking forward to host people who share the same Airbnb spirit of community and sharing. The room you’ll be staying in is beautiful and bright with lots of privacy and will accommodate all your needs while you\'re on the road. Its one of three Rooms in this typical Plateaux Apartment with wooden floor, tiny balcony and direct access to the Backyard. Your room will have a queen size bed and is actually the one who gets the most sunlight in the house. The\nneighborhood_overview=>As for the area, you\'ll be spoiled as you\'ll find everything in walking distance, like: - for the morning\'s best bloody bakery ever "Kouign-Amann", a french bretonne style bakery with croissants and chocolatines to die for plus loads of other delicious pastries (1 min) - The toughest competition of coffee shops in whole Montreal among them "Khawa Cafe" with great coffee and amazing Couscous for lunch, "Le Couteau" where coffee is art or the super friendly window in the Wall "la distributrice"  - for healthy lunches and Lunch packs for the road there is nothing better than "trip de bouffe"  -for  the whole dose of Montreal we have "La Banquise" and "Schwart\'z"  each 10 min by foot from our house -the beautiful Mont Royal Park with its iconic hill and great view over the whole city just 10 min from our doorstep if you want to feel out of town while you\'re actually right in the middle of it  -"JR Cyclery" is renting quality bikes for unbeatable 15 $ for 4 hours or 24 $ for 24 hours, Other\nnotes=>Last but not least about me... I am a German Chef and I love my profession because it lets me combine my passion for food with my passion for travel and meeting new people. I love to discover new country\'s and like to let my mind be broadened by new people, new cultures  and new food! As already mentioned I really believe in the Values of Airbnb and the sharing economy. For this reason it is very important to me that people don\'t take my place simply as a cheap replacement for a hotel. People who stay with me are usually having a great time, not only cause the room is nicely decorated or the place is so central but because they find a personal note that they wouldn\'t find in a hotel. However this only works if people are open minded and don\'t take things for granted. For this Reason I will simply refuse any r ...
#  'Metadata: listing_url=>https://www.airbnb.com/rooms/1886978\nname=>Sunny & Budget Friendly\nsummary=>...SEE MORE OF NY, PAY LESS, & STAY IN COMFORT -Sunny room, accommodates 2. -Wi-Fi -Our subway is the "L" train - EAST 105 STREET station. (Feel free to check the travel time to all the places you would like to visit). -Short walk to L train.\nspace=>The room:  Sunny and Budget Friendly room located on the top floor of our 3 floor townhouse.  It has a full size 10" memory foam mattress that comfortably accommodates 2 people.  The room is a nice size with closet space, wood floors and large window.   Our home:  Is a 3 floor townhouse with a total of 6 guest bedrooms, 2 kitchens,  3 bathrooms, front porch and backyard. We adore the people that we host and work hard to keep a clean and harmonious space for our guests.\ndescription=>...SEE MORE OF NY, PAY LESS, & STAY IN COMFORT -Sunny room, accommodates 2. -Wi-Fi -Our subway is the "L" train - EAST 105 STREET station. (Feel free to check the travel time to all the places you would like to visit). -Short walk to L train. The room:  Sunny and Budget Friendly room located on the top floor of our 3 floor townhouse.  It has a full size 10" memory foam mattress that comfortably accommodates 2 people.  The room is a nice size with closet space, wood floors and large window.   Our home:  Is a 3 floor townhouse with a total of 6 guest bedrooms, 2 kitchens,  3 bathrooms, front porch and backyard. We adore the people that we host and work hard to keep a clean and harmonious space for our guests. Guest will have access to all the common areas. The neighborhood is great for people who love nature and outdoor activities.  We are near the Jamaica Bay Riding Academy, Gateway National Park and Canarsie Pier.  If you like bike riding you could take the Gateway National Park bike p\nneighborhood_overview=>The neighborhood is great for people who love nature and outdoor activities.  We are near the Jamaica Bay Riding Academy, Gateway National Park and Canarsie Pier.  If you like bike riding you could take the Gateway National Park bike path to Brighton Beach--the ride along the water is beautiful and peaceful. As far as cafes-- there are a few spots in Canarsie but I prefer to take the L train to Williamsburg or Downtown Brooklyn to go to some of Brooklyn\'s most revere hip spots.  The total ride to the hippest areas in Brooklyn is about 15 to 30 min depending on the area and on the (Website hidden by Airbnb) Manhattan the first stop is 40 min).  By-the-way, I\'ve seen other posting with spaces  in Canarsie that are located further away from our block, and they are claiming 20 to 30 min to Manhattan--- this is a lie.   Our space is 3 blocks away from the L train and door to door  to 1st Avenue/14 Street (first stop in Manhattan on the L train) it is 40 min.  This is the minimum time you co\nnotes=>We are not 20 min away from Manhattan but we are budget friendly and in a nice safe location.  Our neighbors are great, they appreciate diversity and would be friendly towards you.  As for us we love meeting new people, we are welcoming and will make your comfort our priority. We want to offer you a home away from home and a fabulous stay in NY for a fraction of the cost.\naccess=>Guest will have access to all the common areas.\ninteraction=>\nhouse_rules=>Keep house clean and be mindful of others. No street shoes in the house,bring sleepers. No loud music after 8 pm. To live well with others it is important to practice proper hygiene. Kindly wear deodorant and clean yourself daily. Help us maintain a nice smelling house :-).\nproperty_type=>Townhouse\nroom_type=>Private room\nbed_type=>Real Bed\naccommodates=>2\nbedrooms=>1.0\nbeds=>1.0\nnumber_of_reviews=>78\nbathrooms=>1.0\namenities=>["Internet", "Wifi", "Air conditioning", "Kitchen", "Free parking on premises", "Free street parking", "Heating", "Smoke detector", "Carbon monoxide detector", "First aid kit", "Fire extinguisher", "Essentials", "Shampoo" ...
#  'Metadata: listing_url=>https://www.airbnb.com/rooms/1092760\nname=>Private Entrance - Backyard Summer Dining - Enjoy\nsummary=>If you appreciate the natives in the outer boroughs, we appreciate you as guest.  Brooklyn has become very popular among Brooklynites and new comers.  While visiting NYC, if you are looking for crowds, museums and shopping, visit Manhattan.  Welcome!\nspace=>TRANSPORTATION IS SO IMPORTANT -  APARTMENT IS LOCATED TO EASY AND CONVENIENT TRAVELS -  WHILE STAYING AT THIS: Spacious and comfortable guest suite (Website hidden by Airbnb) Bathroom, open kitchen/entertaining area.     - Access to the garden for summer days and evenings.   The host will interact with the guest, if needed because we respect your privacy and vacation time.\ndescription=>If you appreciate the natives in the outer boroughs, we appreciate you as guest.  Brooklyn has become very popular among Brooklynites and new comers.  While visiting NYC, if you are looking for crowds, museums and shopping, visit Manhattan.  Welcome! TRANSPORTATION IS SO IMPORTANT -  APARTMENT IS LOCATED TO EASY AND CONVENIENT TRAVELS -  WHILE STAYING AT THIS: Spacious and comfortable guest suite (Website hidden by Airbnb) Bathroom, open kitchen/entertaining area.     - Access to the garden for summer days and evenings.   The host will interact with the guest, if needed because we respect your privacy and vacation time. Backyard access. Due to construction in the area, the yard has been compromised therefore esthetically not pleasing to the eye but still can be used. We respect your privacy so will not interfere with your visit. We are not offering a hotel experience, yet a friendly and family environment.  (Please do not bring people to hang out, party or sleepovers - each additional \nneighborhood_overview=>Neighborhood is a diverse culture/eclectic with townhouses, apartment buildings, places for eating, bars, banking, and supermarket. There is major construction around the neighborhood and new construction next door.  Unfortunately, due to construction with digging/breaking ground, we have unfriendly critters (rodents) popping up in the late hours in the streets/subways.  We Brooklynites can\'t wait till beautifying the neighborhood, especially on our block is completed.  This is just an FYI.\nnotes=>IMPORTAN (Website hidden by Airbnb) The Queen Size bed is a Select Comfort Bed - The mattress is controlled (by remote) for a soft or hard feel "your choice comfort", every guest choice is personal.  -     The neighborhood is quiet at night, much traffic during the day which could be noisy due to buses and delivery trucks (not totally distracting unless you are super noise sensitive, there are earplugs).  Presently, there is construction on the block from homes being renovated or built so construction crew starts to work as early as 8 a.m.  -    Just an FYI...     --   Please note the nightly booking rate is for two people.  If a confirmed booking is for one person, any additional person checking in after confirmed booking will have to pay a nightly rate per person upon request.   -    Airconditioner is in the apartment (utilized summer dates June 1 until Sept 30) unless extremely hot, want to make you comfortable, controlled by remote. Please turn off AC and lights when out for the da\naccess=>Backyard access. Due to construction in the area, the yard has been compromised therefore esthetically not pleasing to the eye but still can be used.\ninteraction=>We respect your privacy so will not interfere with your visit. We are not offering a hotel experience, yet a friendly and family environment.  (Please do not bring people to hang out, party or sleepovers - each additional person will be charged a nightly rate whether visiting or staying).\nhouse_rules=>No smoking, No pets.  Sanitary napkins, Tampons and Bounty napkins must be placed in the trash, NOT IN TOILET BOWL.  PLEASE DO NOT use hair dye/color.  Turn off lights, air conditioner and television when out enjo ...
